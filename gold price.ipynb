# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf

# %%
df=yf.download('GLD','2000-01-01','2023-07-04', auto_adjust=True)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df=df[['Close']]

# %%
df=df.dropna()

# %%
sns.heatmap(df.dropna(),annot=True )
# Out:
# <Axes: ylabel='Date'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4686 entries, 2004-11-18 to 2023-07-03
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   4686 non-null   float64
# dtypes: float64(1)
# memory usage: 73.2 KB

# %%
df.plot(figsize=(10,7))
plt.ylabel("gold ETF Prices")
plt.title("gold ETF price series")
plt.show()

# %%
df['S_1'] =df['Close'].rolling(window=1).mean()
df['S_10'] =df['Close'].rolling(window=10).mean()
df['next_day_price']=df['Close'].shift(-1)

# %%
df=df.dropna()
X=df[['S_1','S_10']]
y=df['next_day_price']

# %%
t=0.8
t =int(t*len(df))
X_train =X[t:]
y_test =y[t:]

# %%
from sklearn.linear_model import LinearRegression
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 from sklearn.linear_model import LinearRegression
#
# ModuleNotFoundError: No module named 'sklearn'
